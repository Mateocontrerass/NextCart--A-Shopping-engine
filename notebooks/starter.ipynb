# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
kz = pd.read_csv("../data/kz.csv")
kz
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 4        2020-04-24 19:16:21 UTC  2294584263154074236  2273948316817424439
# ...                          ...                  ...                  ...
# 2633516  2020-11-21 10:10:01 UTC  2388440981134693942  1515966223526602848
# 2633517  2020-11-21 10:10:13 UTC  2388440981134693943  1515966223509089282
# 2633518  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509089917
# 2633519  2020-11-21 10:10:30 UTC  2388440981134693944  2273948184839454837
# 2633520  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509127566
#
# ...

# %%
kz.category_code.value_counts()
# Out:
# category_code
# electronics.smartphone              357682
# appliances.kitchen.refrigerators     77386
# 16.18                                72969
# electronics.video.tv                 71711
# computers.notebook                   71436
#                                      ...
# 1388.87                                  1
# 752.29                                   1
# 240.72                                   1
# 71.74                                    1
# 62.01                                    1
# Name: count, Length: 510, dtype: int64

# %%
(kz.category_code.value_counts(normalize=True) * 100).head(30)
# Out:
# category_code
# electronics.smartphone                    17.695475
# appliances.kitchen.refrigerators           3.828490
# 16.18                                      3.609970
# electronics.video.tv                       3.547733
# computers.notebook                         3.534128
# appliances.environment.vacuum              3.288496
# electronics.audio.headphone                3.273061
# appliances.kitchen.kettle                  3.102875
# appliances.kitchen.washer                  2.783084
# furniture.kitchen.table                    2.756863
# computers.peripherals.mouse                2.242546
# 57.87                                      2.233641
# 8.10                                       2.098184
# 9.26                                       2.023975
# appliances.iron                            1.989246
# 29.63                                      1.918896
# appliances.kitchen.blender                 1.815498
# appliances.personal.scales                 1.628145
# ...

# %%
mkt_amazon = pd.read_csv("../data/marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv")

# %%
mkt_amazon.sample(5)
# Out:
#                                Uniq Id  \
# 3572  dd6beed921a0a78aeed1cdb42e4a78d2
# 2121  9a3631743134887e98b7feb2f4eb4e31
# 14    1ecccb43e0f5c0162218371916ffa553
# 3473  dfddf9f85384157764f6a9bf41b86706
# 3139  a6e7147738c1dc029c160d6f519a2661
#
#                                            Product Name  Brand Name  Asin  \
# 3572  Costume Sunglasses Sesame Street Bert Sun-Stac...         NaN   NaN
# 2121  Ideal SNO Scapes Scene Creator Set Kids Outdoo...         NaN   NaN
# 14    C&D Visionary DC Comic Originals Flash Logo St...         NaN   NaN
# 3473  Rubie's Star Wars Classic Luke Skywalker Child...         NaN   NaN
# 3139  Frozen Magic Touch Guitar - Features Songs - L...         NaN   NaN
#
#                                                Category  Upc Ean Code  \
# 3572  Clothing, Shoes & Jewelry | Men | Accessories ...  878599411930
# 2121  Toys & Games | Arts & Crafts | Craft Kits | Pa...           NaN
# ...

# %%
mkt_amazon["About Product"][0]
# Out:
# "Make sure this fits by entering your model number. | RESPONSIVE FLEX: The Crossbow features a bamboo core encased in triaxial fiberglass and HD plastic for a responsive flex pattern that’s second to none. Pumping & carving have never been so satisfying! Flex 2 is recommended for people 120 to 170 pounds. | COREFLEX TECH: CoreFlex construction is water resistant, impact resistant, scratch resistant and has a flex like you won’t believe. These boards combine fiberglass, epoxy, HD plastic and bamboo to create a perfect blend of performance and strength. | INSPIRED BY THE NORTHWEST: Our founding ideal is chasing adventure & riding the best boards possible, inspired by the hills, waves, beaches & mountains all around our headquarters in the Northwest | BEST IN THE WORLD: DB was founded out of sheer love of longboarding with a mission to create the best custom longboards in the world, to do it sustainably, & to treat customers & employees like family | BEYOND COMPARE: Try our skateboards 
# ...

# %%
mkt_amazon["Category"].unique()
# Out:
# <StringArray>
# ['Sports & Outdoors | Outdoor Recreation | Skates, Skateboards & Scooters | Skateboarding | Standard Skateboards & Longboards | Longboards',
#                                                                                 'Toys & Games | Learning & Education | Science Kits & Toys',
#                                                                                                 'Toys & Games | Arts & Crafts | Craft Kits',
#                                                           'Toys & Games | Hobbies | Models & Model Kits | Model Kits | Airplane & Jet Kits',
#                                                                                                   'Toys & Games | Puzzles | Jigsaw Puzzles',
#                                                                                                                                         nan,
# ...
